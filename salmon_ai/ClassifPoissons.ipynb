# %% [markdown]
# <h1> Classification de poissons </h1>

# %% [markdown]
# ## Téléchargement de la base de données

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import preprocessing
from tensorflow.keras.preprocessing import image_dataset_from_directory
# Out:
# /home/lucien/anaconda3/envs/tf/lib/python3.9/site-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.15) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
IMG_SIZE = 224
train_ds = tf.keras.utils.image_dataset_from_directory(
    directory='/home/lucien/Documents/data_fish/Salmonidae_split/train',
    labels='inferred',
    label_mode='categorical',
    shuffle = False,
    batch_size=16,
    image_size=(IMG_SIZE, IMG_SIZE))
# Out:
# Found 3000 files belonging to 12 classes.

# %%
class_names = train_ds.class_names
print(class_names)
nb_classes = len(class_names)
print(nb_classes)
# Out:
# ['Grand_Corégone', 'Ombre_Commun', 'Saumon_Atlantique', 'Saumon_Chinook', 'Saumon_Coho', 'Saumon_Kéta', 'Saumon_Rose', 'Saumon_Rouge', 'Touladi', 'Truite_Arc-En-Ciel', 'Truite_Commune_Européenne', 'Truite_Fardée']
# 12

# %% [markdown]
# ## Chargement des données

# %%
from tensorflow import keras
from tensorflow.keras import layers

# %%
# Paramètres
IMG_SIZE = 224 # pour utiliser ResNet

# %%
# Récupération des dataset pour l'entraînement (train, val)
# Shuffle à false pour avoir accès aux images depuis
# leur chemin d'accès avec train_ds.file_paths
train_ds = keras.utils.image_dataset_from_directory(
    directory='/home/lucien/Documents/data_fish/Salmonidae_split/train/',
    labels='inferred',
    label_mode='categorical',
    shuffle = False,
    batch_size=4,
    image_size=(IMG_SIZE, IMG_SIZE))

validation_ds = keras.utils.image_dataset_from_directory(
    directory='/home/lucien/Documents/data_fish/Salmonidae_split/val/',
    labels='inferred',
    label_mode='categorical',
    batch_size=4,
    image_size=(IMG_SIZE, IMG_SIZE))
# Out:
# Found 3000 files belonging to 12 classes.
# Found 371 files belonging to 12 classes.

# %% [markdown]
# ## Augmentation de données : Sequence et Albumentations

# %%
from albumentations import (Compose, Rotate, HorizontalFlip, VerticalFlip, Affine, RandomBrightnessContrast, ChannelShuffle)
import albumentations as A

AUGMENTATIONS_TRAIN = Compose([
    Rotate(limit=[0,100], p=0.5),
    HorizontalFlip(p=0.5),
    VerticalFlip(p=0.5),
    Affine(shear=[-45, 45], p=0.5),
    RandomBrightnessContrast(p=0.5)
])

# %%
from tensorflow.keras.utils import Sequence
import numpy as np
import cv2 as cv

class PoissonSequence(Sequence):
    # Initialisation de la séquence avec différents paramètres
    def __init__(self, x_train, y_train, batch_size, augmentations):
        self.x_train = x_train
        self.y_train = y_train
        self.classes = class_names
        self.batch_size = batch_size
        self.augment = augmentations
        self.indices1 = np.arange(len(x_train))
        np.random.shuffle(self.indices1) # Les indices permettent d'accéder
        # aux données et sont randomisés à chaque epoch pour varier la composition
        # des batches au cours de l'entraînement

    # Fonction calculant le nombre de pas de descente du gradient par epoch
    def __len__(self):
        return int(np.ceil(self.x_train.shape[0] / float(self.batch_size)))
    
    # Application de l'augmentation de données à chaque image du batch
    def apply_augmentation(self, bx, by):

        batch_x = np.zeros((bx.shape[0], IMG_SIZE, IMG_SIZE, 3))
        batch_y = by
        
        # Pour chaque image du batch
        for i in range(len(bx)):
            class_labels = []
            class_id = np.argmax(by[i])
            class_labels.append(self.classes[class_id])

            # Application de l'augmentation à l'image
            img = cv.imread(bx[i])
            img = cv.cvtColor(img, cv.COLOR_BGR2RGB)

            #on veut que notre image soit de taille 224 sur 224
            img = cv.resize(img, (224,224))

            transformed = self.augment(image=img)
            batch_x[i] = transformed['image']
      
        return batch_x, batch_y

    # Fonction appelée à chaque nouveau batch : sélection et augmentation des données
    # idx = position du batch (idx = 5 => on prend le 5ème batch)
    def __getitem__(self, idx):
        batch_x = self.x_train[self.indices1[idx * self.batch_size:(idx + 1) * self.batch_size]]
        batch_y = self.y_train[self.indices1[idx * self.batch_size:(idx + 1) * self.batch_size]]
           
        batch_x, batch_y = self.apply_augmentation(batch_x, batch_y)

        # Normalisation des données
        batch_x = tf.keras.applications.resnet.preprocess_input(batch_x)
        
        return batch_x, batch_y

    # Fonction appelée à la fin d'un epoch ; on randomise les indices d'accès aux données
    def on_epoch_end(self):
        np.random.shuffle(self.indices1)

# %%
# Les images sont stockées avec les chemins d'accès
import numpy as np
import os
print(nb_classes)
taille_train = 0
for i in range(nb_classes):
  taille_train += len(os.listdir('/home/lucien/Documents/data_fish/Salmonidae_split/train/'+class_names[i]))
print(taille_train)
taille_val = 0
for i in range(nb_classes):
  taille_val += len(os.listdir('/home/lucien/Documents/data_fish/Salmonidae_split/val/'+class_names[i]))
x_train = np.array(train_ds.file_paths)
y_train = np.zeros((taille_train, nb_classes))#rentrer la taille du train

ind_data = 0
for bx, by in train_ds.as_numpy_iterator():
  y_train[ind_data:ind_data+bx.shape[0]] = by
  ind_data += bx.shape[0]
# Out:
# 12
# 3000

# %%
# Instanciation de la Sequence
train_ds_aug = PoissonSequence(x_train, y_train, batch_size=4, augmentations=AUGMENTATIONS_TRAIN)

# Normalisation des données de validation
import numpy as np
import tensorflow as tf

x_val = np.zeros((taille_val, IMG_SIZE, IMG_SIZE, 3))#rentrer la taille du valval
y_val = np.zeros((taille_val, nb_classes))#rentrer la taille du val

ind_data = 0
for bx, by in validation_ds.as_numpy_iterator():
  x_val[ind_data:ind_data+bx.shape[0]] = bx
  y_val[ind_data:ind_data+bx.shape[0]] = by
  ind_data += bx.shape[0]

x_val = tf.keras.applications.resnet.preprocess_input(x_val)

# %% [markdown]
# ## Création du modèle

# %%
from tensorflow.keras import regularizers
from tensorflow.keras import optimizers
import tensorflow as tf

# %% [markdown]
# ### Poids d'imagenet

# %%
conv_base = keras.applications.resnet.ResNet50(
    include_top=False,
    weights='imagenet',
    input_tensor=None,
    input_shape=(IMG_SIZE, IMG_SIZE, 3),
    pooling=None,
    classes=nb_classes,
) #transfer learning sur imagenet

model = keras.Sequential(
    [
        conv_base,
        layers.GlobalAveragePooling2D(),
        layers.Dense(nb_classes, kernel_regularizer=regularizers.L2(1e-4), activation='softmax')
    ]
)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 12)                24588
#
# =================================================================
# Total params: 23,612,300
# Trainable params: 23,559,180
# Non-trainable params: 53,120
# _________________________________________________________________

# %%
loss = keras.losses.CategoricalCrossentropy()

# %% [markdown]
# ## Entraînement du modèle

# %%
# Ajout de l'optimiseur, de la fonction coût et des métriques
lr = 1e-3
model.compile(optimizers.SGD(learning_rate=lr, momentum=0.9), loss=loss, metrics=['categorical_accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])

# %%
# Les callbacks, là où on sauvegarde les poids du réseau

#filepath = path to save the model at the end of each epoch

model_checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(
    filepath='/home/lucien/Documents/final_project_Essec/salmon_ai/model_poisson/model', 
    save_weights_only=True,
    monitor='val_categorical_accuracy',
    mode='max',
    save_best_only=True,
    verbose=1)

early_stopping_cb = tf.keras.callbacks.EarlyStopping(
   monitor="val_categorical_accuracy",
   min_delta=0.01,
   patience=8,
   verbose=1,
   mode="auto")

reduce_lr_cb = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_categorical_accuracy', factor=0.1,
                              patience=5, min_lr=0.00001, verbose=1) #on choisit un learning rate qui permet de bouger un tout petit peu si on est bloqué dans un extremum local

# %%
history = model.fit(train_ds_aug, epochs=30, validation_data = (x_val, y_val), callbacks=[model_checkpoint_cb, reduce_lr_cb])
# Out:
# Epoch 1/30
# 750/750 [==============================] - ETA: 0s - loss: 2.3238 - categorical_accuracy: 0.2237 - precision: 0.4372 - recall: 0.0627
# Epoch 1: val_categorical_accuracy improved from -inf to 0.31536, saving model to /home/lucien/Documents/final_project_Essec/salmon_ai/model_poisson/model
# 750/750 [==============================] - 53s 57ms/step - loss: 2.3238 - categorical_accuracy: 0.2237 - precision: 0.4372 - recall: 0.0627 - val_loss: 2.2875 - val_categorical_accuracy: 0.3154 - val_precision: 0.4797 - val_recall: 0.1914 - lr: 0.0010
# Epoch 2/30
# 750/750 [==============================] - ETA: 0s - loss: 2.0295 - categorical_accuracy: 0.2993 - precision: 0.5517 - recall: 0.0853
# Epoch 2: val_categorical_accuracy improved from 0.31536 to 0.36658, saving model to /home/lucien/Documents/final_project_Essec/salmon_ai/model_poisson/model
# 750/750 [==============================] - 41s 54ms/step - loss: 2.0295 - categorical_accuracy: 0.2993 - precision: 0.5517 - recall: 0.0853 - val_loss: 1.9524 - val_categorical_accuracy: 0.3666 - val_precision: 0.5620 - val_recall: 0.2075 - lr: 0.0010
# Epoch 3/30
# 750/750 [==============================] - ETA: 0s - loss: 1.8824 - categorical_accuracy: 0.3573 - precision: 0.6769 - recall: 0.1320
# Epoch 3: val_categorical_accuracy did not improve from 0.36658
# 750/750 [==============================] - 40s 54ms/step - loss: 1.8824 - categorical_accuracy: 0.3573 - precision: 0.6769 - recall: 0.1320 - val_loss: 3.0481 - val_categorical_accuracy: 0.3100 - val_precision: 0.4061 - val_recall: 0.1806 - lr: 0.0010
# Epoch 4/30
# 750/750 [==============================] - ETA: 0s - loss: 1.7801 - categorical_accuracy: 0.3860 - precision: 0.7068 - recall: 0.1800
# Epoch 4: val_categorical_accuracy did not improve from 0.36658
# 750/750 [==============================] - 40s 54ms/step - loss: 1.7801 - categorical_accuracy: 0.3860 - precision: 0.7068 - recall: 0.1800 - val_loss: 2.4517 - val_categorical_accuracy: 0.2992 - val_precision: 0.3911 - val_recall: 0.2129 - lr: 0.0010
# Epoch 5/30
# 750/750 [==============================] - ETA: 0s - loss: 1.7088 - categorical_accuracy: 0.4137 - precision: 0.6892 - recall: 0.1937
# Epoch 5: val_categorical_accuracy improved from 0.36658 to 0.43666, saving model to /home/lucien/Documents/final_project_Essec/salmon_ai/model_poisson/model
# 750/750 [==============================] - 41s 54ms/step - loss: 1.7088 - categorical_accuracy: 0.4137 - precision: 0.6892 - recall: 0.1937 - val_loss: 1.7332 - val_categorical_accuracy: 0.4367 - val_precision: 0.5812 - val_recall: 0.2992 - lr: 0.0010
# Epoch 6/30
# 750/750 [==============================] - ETA: 0s - loss: 1.6467 - categorical_accuracy: 0.4350 - precision: 0.7069 - recall: 0.2340
# Epoch 6: val_categorical_accuracy did not improve from 0.43666
# 750/750 [==============================] - 40s 54ms/step - loss: 1.6467 - categorical_accuracy: 0.4350 - precision: 0.7069 - recall: 0.2340 - val_loss: 1.7872 - val_categorical_accuracy: 0.4124 - val_precision: 0.5751 - val_recall: 0.2992 - lr: 0.0010
# Epoch 7/30
# 750/750 [==============================] - ETA: 0s - loss: 1.5783 - categorical_accuracy: 0.4587 - precision: 0.7314 - recall: 0.2587
# Epoch 7: val_categorical_accuracy did not improve from 0.43666
# 750/750 [==============================] - 40s 54ms/step - loss: 1.5783 - categorical_accuracy: 0.4587 - precision: 0.7314 - recall: 0.2587 - val_loss: 2.4224 - val_categorical_accuracy: 0.3450 - val_precision: 0.4416 - val_recall: 0.2345 - lr: 0.0010
# Epoch 8/30
# 750/750 [==============================] - ETA: 0s - loss: 1.5509 - categorical_accuracy: 0.4653 - precision: 0.7182 - recall: 0.2633
# Epoch 8: val_categorical_accuracy did not improve from 0.43666
# 750/750 [==============================] - 40s 54ms/step - loss: 1.5509 - categorical_accuracy: 0.4653 - precision: 0.7182 - recall: 0.2633 - val_loss: 1.9689 - val_categorical_accuracy: 0.4151 - val_precision: 0.5451 - val_recall: 0.3423 - lr: 0.0010
# Epoch 9/30
# 750/750 [==============================] - ETA: 0s - loss: 1.4841 - categorical_accuracy: 0.4953 - precision: 0.7423 - recall: 0.2987
# Epoch 9: val_categorical_accuracy improved from 0.43666 to 0.44205, saving model to /home/lucien/Documents/final_project_Essec/salmon_ai/model_poisson/model
# 750/750 [==============================] - 41s 54ms/step - loss: 1.4841 - categorical_accuracy: 0.4953 - precision: 0.7423 - recall: 0.2987 - val_loss: 1.8654 - val_categorical_accuracy: 0.4420 - val_precision: 0.5887 - val_recall: 0.3666 - lr: 0.0010
# Epoch 10/30
# 750/750 [==============================] - ETA: 0s - loss: 1.4331 - categorical_accuracy: 0.5117 - precision: 0.7628 - recall: 0.3173
# Epoch 10: val_categorical_accuracy did not improve from 0.44205
# 750/750 [==============================] - 40s 54ms/step - loss: 1.4331 - categorical_accuracy: 0.5117 - precision: 0.7628 - recall: 0.3173 - val_loss: 2.1432 - val_categorical_accuracy: 0.4232 - val_precision: 0.5075 - val_recall: 0.3639 - lr: 0.0010
# Epoch 11/30
# 750/750 [==============================] - ETA: 0s - loss: 1.3929 - categorical_accuracy: 0.5303 - precision: 0.7332 - recall: 0.3380
# Epoch 11: val_categorical_accuracy improved from 0.44205 to 0.45553, saving model to /home/lucien/Documents/final_project_Essec/salmon_ai/model_poisson/model
# 750/750 [==============================] - 41s 54ms/step - loss: 1.3929 - categorical_accuracy: 0.5303 - precision: 0.7332 - recall: 0.3380 - val_loss: 1.9367 - val_categorical_accuracy: 0.4555 - val_precision: 0.5321 - val_recall: 0.3801 - lr: 0.0010
# Epoch 12/30
# 750/750 [==============================] - ETA: 0s - loss: 1.3598 - categorical_accuracy: 0.5397 - precision: 0.7530 - recall: 0.3547
# Epoch 12: val_categorical_accuracy did not improve from 0.45553
# 750/750 [==============================] - 40s 54ms/step - loss: 1.3598 - categorical_accuracy: 0.5397 - precision: 0.7530 - recall: 0.3547 - val_loss: 2.1212 - val_categorical_accuracy: 0.4528 - val_precision: 0.5307 - val_recall: 0.3962 - lr: 0.0010
# Epoch 13/30
# 750/750 [==============================] - ETA: 0s - loss: 1.2983 - categorical_accuracy: 0.5597 - precision: 0.7742 - recall: 0.3817
# Epoch 13: val_categorical_accuracy improved from 0.45553 to 0.45822, saving model to /home/lucien/Documents/final_project_Essec/salmon_ai/model_poisson/model
# 750/750 [==============================] - 41s 54ms/step - loss: 1.2983 - categorical_accuracy: 0.5597 - precision: 0.7742 - recall: 0.3817 - val_loss: 2.1336 - val_categorical_accuracy: 0.4582 - val_precision: 0.5438 - val_recall: 0.4016 - lr: 0.0010
# Epoch 14/30
# 750/750 [==============================] - ETA: 0s - loss: 1.3085 - categorical_accuracy: 0.5650 - precision: 0.7631 - recall: 0.3877
# Epoch 14: val_categorical_accuracy did not improve from 0.45822
# 750/750 [==============================] - 40s 54ms/step - loss: 1.3085 - categorical_accuracy: 0.5650 - precision: 0.7631 - recall: 0.3877 - val_loss: 2.0125 - val_categorical_accuracy: 0.4447 - val_precision: 0.5328 - val_recall: 0.3720 - lr: 0.0010
# Epoch 15/30
# 750/750 [==============================] - ETA: 0s - loss: 1.2565 - categorical_accuracy: 0.5550 - precision: 0.7490 - recall: 0.3930
# Epoch 15: val_categorical_accuracy did not improve from 0.45822
# 750/750 [==============================] - 40s 54ms/step - loss: 1.2565 - categorical_accuracy: 0.5550 - precision: 0.7490 - recall: 0.3930 - val_loss: 2.1994 - val_categorical_accuracy: 0.4232 - val_precision: 0.5041 - val_recall: 0.3342 - lr: 0.0010
# Epoch 16/30
# 750/750 [==============================] - ETA: 0s - loss: 1.2272 - categorical_accuracy: 0.5907 - precision: 0.7680 - recall: 0.4160
# Epoch 16: val_categorical_accuracy did not improve from 0.45822
# 750/750 [==============================] - 40s 54ms/step - loss: 1.2272 - categorical_accuracy: 0.5907 - precision: 0.7680 - recall: 0.4160 - val_loss: 2.4960 - val_categorical_accuracy: 0.4232 - val_precision: 0.5038 - val_recall: 0.3558 - lr: 0.0010
# Epoch 17/30
# 750/750 [==============================] - ETA: 0s - loss: 1.1748 - categorical_accuracy: 0.6060 - precision: 0.7836 - recall: 0.4490
# Epoch 17: val_categorical_accuracy improved from 0.45822 to 0.46092, saving model to /home/lucien/Documents/final_project_Essec/salmon_ai/model_poisson/model
# 750/750 [==============================] - 41s 55ms/step - loss: 1.1748 - categorical_accuracy: 0.6060 - precision: 0.7836 - recall: 0.4490 - val_loss: 2.5396 - val_categorical_accuracy: 0.4609 - val_precision: 0.5213 - val_recall: 0.3962 - lr: 0.0010
# Epoch 18/30
# 750/750 [==============================] - ETA: 0s - loss: 1.1664 - categorical_accuracy: 0.6087 - precision: 0.7786 - recall: 0.4477
# Epoch 18: val_categorical_accuracy did not improve from 0.46092
# 750/750 [==============================] - 40s 54ms/step - loss: 1.1664 - categorical_accuracy: 0.6087 - precision: 0.7786 - recall: 0.4477 - val_loss: 2.2966 - val_categorical_accuracy: 0.4528 - val_precision: 0.5052 - val_recall: 0.3908 - lr: 0.0010
# Epoch 19/30
# 750/750 [==============================] - ETA: 0s - loss: 1.1316 - categorical_accuracy: 0.6217 - precision: 0.7871 - recall: 0.4707
# Epoch 19: val_categorical_accuracy did not improve from 0.46092
# 750/750 [==============================] - 40s 54ms/step - loss: 1.1316 - categorical_accuracy: 0.6217 - precision: 0.7871 - recall: 0.4707 - val_loss: 2.3089 - val_categorical_accuracy: 0.4474 - val_precision: 0.5156 - val_recall: 0.4016 - lr: 0.0010
# Epoch 20/30
# 750/750 [==============================] - ETA: 0s - loss: 1.1092 - categorical_accuracy: 0.6217 - precision: 0.7975 - recall: 0.4830
# Epoch 20: val_categorical_accuracy did not improve from 0.46092
# 750/750 [==============================] - 40s 54ms/step - loss: 1.1092 - categorical_accuracy: 0.6217 - precision: 0.7975 - recall: 0.4830 - val_loss: 3.0205 - val_categorical_accuracy: 0.4043 - val_precision: 0.4475 - val_recall: 0.3558 - lr: 0.0010
# Epoch 21/30
# 750/750 [==============================] - ETA: 0s - loss: 1.0829 - categorical_accuracy: 0.6357 - precision: 0.8011 - recall: 0.4860
# Epoch 21: val_categorical_accuracy improved from 0.46092 to 0.48518, saving model to /home/lucien/Documents/final_project_Essec/salmon_ai/model_poisson/model
# 750/750 [==============================] - 41s 55ms/step - loss: 1.0829 - categorical_accuracy: 0.6357 - precision: 0.8011 - recall: 0.4860 - val_loss: 2.4683 - val_categorical_accuracy: 0.4852 - val_precision: 0.5362 - val_recall: 0.4394 - lr: 0.0010
# Epoch 22/30
# 750/750 [==============================] - ETA: 0s - loss: 1.0428 - categorical_accuracy: 0.6523 - precision: 0.8008 - recall: 0.5053
# Epoch 22: val_categorical_accuracy did not improve from 0.48518
# 750/750 [==============================] - 40s 54ms/step - loss: 1.0428 - categorical_accuracy: 0.6523 - precision: 0.8008 - recall: 0.5053 - val_loss: 2.7353 - val_categorical_accuracy: 0.4555 - val_precision: 0.5065 - val_recall: 0.4178 - lr: 0.0010
# Epoch 23/30
# 750/750 [==============================] - ETA: 0s - loss: 1.0570 - categorical_accuracy: 0.6433 - precision: 0.7988 - recall: 0.5133
# Epoch 23: val_categorical_accuracy did not improve from 0.48518
# 750/750 [==============================] - 40s 54ms/step - loss: 1.0570 - categorical_accuracy: 0.6433 - precision: 0.7988 - recall: 0.5133 - val_loss: 2.7125 - val_categorical_accuracy: 0.4151 - val_precision: 0.4678 - val_recall: 0.3720 - lr: 0.0010
# Epoch 24/30
# 750/750 [==============================] - ETA: 0s - loss: 0.9747 - categorical_accuracy: 0.6720 - precision: 0.8132 - recall: 0.5530
# Epoch 24: val_categorical_accuracy did not improve from 0.48518
# 750/750 [==============================] - 40s 54ms/step - loss: 0.9747 - categorical_accuracy: 0.6720 - precision: 0.8132 - recall: 0.5530 - val_loss: 2.6478 - val_categorical_accuracy: 0.4717 - val_precision: 0.4951 - val_recall: 0.4097 - lr: 0.0010
# Epoch 25/30
# 750/750 [==============================] - ETA: 0s - loss: 0.9692 - categorical_accuracy: 0.6820 - precision: 0.8048 - recall: 0.5497
# Epoch 25: val_categorical_accuracy did not improve from 0.48518
# 750/750 [==============================] - 40s 54ms/step - loss: 0.9692 - categorical_accuracy: 0.6820 - precision: 0.8048 - recall: 0.5497 - val_loss: 3.3917 - val_categorical_accuracy: 0.4097 - val_precision: 0.4359 - val_recall: 0.3666 - lr: 0.0010
# Epoch 26/30
# 750/750 [==============================] - ETA: 0s - loss: 0.9689 - categorical_accuracy: 0.6800 - precision: 0.8010 - recall: 0.5420
# Epoch 26: val_categorical_accuracy did not improve from 0.48518
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 750/750 [==============================] - 40s 54ms/step - loss: 0.9689 - categorical_accuracy: 0.6800 - precision: 0.8010 - recall: 0.5420 - val_loss: 3.1403 - val_categorical_accuracy: 0.4205 - val_precision: 0.4620 - val_recall: 0.3774 - lr: 0.0010
# Epoch 27/30
# 750/750 [==============================] - ETA: 0s - loss: 0.7731 - categorical_accuracy: 0.7460 - precision: 0.8612 - recall: 0.6247
# Epoch 27: val_categorical_accuracy did not improve from 0.48518
# 750/750 [==============================] - 40s 54ms/step - loss: 0.7731 - categorical_accuracy: 0.7460 - precision: 0.8612 - recall: 0.6247 - val_loss: 2.7406 - val_categorical_accuracy: 0.4852 - val_precision: 0.5321 - val_recall: 0.4474 - lr: 1.0000e-04
# Epoch 28/30
# 750/750 [==============================] - ETA: 0s - loss: 0.6550 - categorical_accuracy: 0.7820 - precision: 0.8880 - recall: 0.6927
# Epoch 28: val_categorical_accuracy did not improve from 0.48518
# 750/750 [==============================] - 40s 54ms/step - loss: 0.6550 - categorical_accuracy: 0.7820 - precision: 0.8880 - recall: 0.6927 - val_loss: 2.7742 - val_categorical_accuracy: 0.4852 - val_precision: 0.5185 - val_recall: 0.4528 - lr: 1.0000e-04
# Epoch 29/30
# 750/750 [==============================] - ETA: 0s - loss: 0.6022 - categorical_accuracy: 0.8073 - precision: 0.8883 - recall: 0.7210
# Epoch 29: val_categorical_accuracy did not improve from 0.48518
# 750/750 [==============================] - 40s 54ms/step - loss: 0.6022 - categorical_accuracy: 0.8073 - precision: 0.8883 - recall: 0.7210 - val_loss: 2.7595 - val_categorical_accuracy: 0.4744 - val_precision: 0.5123 - val_recall: 0.4501 - lr: 1.0000e-04
# Epoch 30/30
# 750/750 [==============================] - ETA: 0s - loss: 0.6035 - categorical_accuracy: 0.8030 - precision: 0.8900 - recall: 0.7230
# Epoch 30: val_categorical_accuracy improved from 0.48518 to 0.49057, saving model to /home/lucien/Documents/final_project_Essec/salmon_ai/model_poisson/model
# 750/750 [==============================] - 41s 55ms/step - loss: 0.6035 - categorical_accuracy: 0.8030 - precision: 0.8900 - recall: 0.7230 - val_loss: 2.9504 - val_categorical_accuracy: 0.4906 - val_precision: 0.5317 - val_recall: 0.4744 - lr: 1.0000e-04
